# %%
class parent:
    def __init__(self,)
    

s=int(input("enter value of s-"))
a=int(input("enter value of a-"))
b=int(input("enter value of b-"))
c=int(input("enter value of c-"))
# Out:
# enter value of s-22
# enter value of a-22
# enter value of b-3
# enter value of c-44

# %%
def get_area(self):
    s=(a+b+c)/2
    return (s*(s-a)*(s-b)*(s-c)) ** 0.5

# %%
class Polygon:

    def __init__(self, n):
        self.number_of_sides = n


class Triangle(Polygon):

    def __init__(self, lengths_of_sides):
        Polygon.__init__(self, 3)
        self.lengths_of_sides = lengths_of_sides  # list of three numbers

    def get_area(self):
        '''return the area of the triangle using the semi-perimeter method'''
        a, b, c = self.lengths_of_sides

        # calculate the semi-perimeter
        s = (a + b + c) / 2
        return (s*(s-a)*(s-b)*(s-c)) ** 0.5

# %%
tri = Triangle([int(input("enter value of a-")), int(input("enter value of b-")), int(input("enter value of c-"))])
print(tri.get_area())
tri.print_num_sides()
# Out:
# enter value of a-3
# enter value of b-4
# enter value of c-5
# 6.0
# There are 3 sides.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-ad9e8496c611> in <module>
# ----> 1 GET /v2/locations/39
#
# NameError: name 'GET' is not defined

# %%
import COVID19Py

# %%
covid19=COVID19Py.COVID19()

# %%
covid19

# %%
covid19 = COVID19Py.COVID19('https://api.rootnet.in/covid19-in/unofficial/covid19india.org')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-58e49981410e> in <module>
# ----> 1 covid19 = COVID19Py.COVID19('https://api.rootnet.in/covid19-in/unofficial/covid19india.org')
#
# C:\ProgramData\Anaconda3\lib\site-packages\COVID19Py\covid19.py in __init__(self, url, data_source)
#      12     def __init__(self, url="https://coronavirus-tracker-api.herokuapp.com", data_source='jhu'):
#      13         self.url = url
# ---> 14         self._valid_data_sources = self._getSources()
#      15         if data_source not in self._valid_data_sources:
#      16             raise ValueError("Invalid data source. Expected one of: %s" % self._valid_data_sources)
#
# C:\ProgramData\Anaconda3\lib\site-packages\COVID19Py\covid19.py in _getSources(self)
#      30         response = requests.get(self.url + "/v2/sources")
#      31         response.raise_for_status()
# ...

# %%
covid19

# %%
covid19.url('https://api.rootnet.in/covid19-in/unofficial/covid19india.org')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-6e1ec8abd09e> in <module>
# ----> 1 covid19.url('https://api.rootnet.in/covid19-in/unofficial/covid19india.org')
#
# TypeError: 'str' object is not callable

# %%
covid19.getAll()
# Out:
# {'latest': {'confirmed': 3041764, 'deaths': 211167, 'recovered': 0},
#  'locations': [{'id': 0,
#    'country': 'Afghanistan',
#    'country_code': 'AF',
#    'country_population': 37172386,
#    'province': '',
#    'last_updated': '2020-04-29T01:39:44.143191Z',
#    'coordinates': {'latitude': '33.0', 'longitude': '65.0'},
#    'latest': {'confirmed': 1703, 'deaths': 57, 'recovered': 0}},
#   {'id': 1,
#    'country': 'Albania',
#    'country_code': 'AL',
#    'country_population': 2866376,
#    'province': '',
#    'last_updated': '2020-04-29T01:39:44.147265Z',
#    'coordinates': {'latitude': '41.1533', 'longitude': '20.1683'},
#    'latest': {'confirmed': 736, 'deaths': 28, 'recovered': 0}},
#   {'id': 2,
#    'country': 'Algeria',
#    'country_code': 'DZ',
#    'country_population': 42228429,
#    'province': '',
#    'last_updated': '2020-04-29T01:39:44.151270Z',
#    'coordinates': {'latitude': '28.0339', 'longitude': '1.6596'},
# ...

# %%
covid19.getLatestChanges()
# Out:
# {'confirmed': 0, 'deaths': 0, 'recovered': 0}

# %%
covid19.getLocations()[131]
# Out:
# {'id': 131,
#  'country': 'India',
#  'country_code': 'IN',
#  'country_population': 1352617328,
#  'province': '',
#  'last_updated': '2020-04-30T02:52:51.879460Z',
#  'coordinates': {'latitude': '21.0', 'longitude': '78.0'},
#  'latest': {'confirmed': 31324, 'deaths': 1008, 'recovered': 0}}

# %%
covid19.getLocationById(131)
covid19.getLocationByCountryCode('IN', timelines=True)
# Out:
# [{'id': 131,
#   'country': 'India',
#   'country_code': 'IN',
#   'country_population': 1352617328,
#   'province': '',
#   'last_updated': '2020-04-29T01:39:44.895819Z',
#   'coordinates': {'latitude': '21.0', 'longitude': '78.0'},
#   'latest': {'confirmed': 29451, 'deaths': 939, 'recovered': 0},
#   'timelines': {'confirmed': {'latest': 29451,
#     'timeline': {'2020-01-22T00:00:00Z': 0,
#      '2020-01-23T00:00:00Z': 0,
#      '2020-01-24T00:00:00Z': 0,
#      '2020-01-25T00:00:00Z': 0,
#      '2020-01-26T00:00:00Z': 0,
#      '2020-01-27T00:00:00Z': 0,
#      '2020-01-28T00:00:00Z': 0,
#      '2020-01-29T00:00:00Z': 0,
#      '2020-01-30T00:00:00Z': 1,
#      '2020-01-31T00:00:00Z': 1,
#      '2020-02-01T00:00:00Z': 1,
#      '2020-02-02T00:00:00Z': 2,
#      '2020-02-03T00:00:00Z': 3,
#      '2020-02-04T00:00:00Z': 3,
#      '2020-02-05T00:00:00Z': 3,
#      '2020-02-06T00:00:00Z': 3,
#      '2020-02-07T00:00:00Z': 3,
#      '2020-02-08T00:00:00Z': 3,
# ...

# %%
changes = covid19.getLatestChanges()
changes
# Out:
# {'confirmed': 0, 'deaths': 0, 'recovered': 0}

# %%
a=covid19.getLocations()[131]
covid19.getLocationByCountryCode
# Out:
# {'id': 131,
#  'country': 'India',
#  'country_code': 'IN',
#  'country_population': 1352617328,
#  'province': '',
#  'last_updated': '2020-04-29T01:39:44.895819Z',
#  'coordinates': {'latitude': '21.0', 'longitude': '78.0'},
#  'latest': {'confirmed': 29451, 'deaths': 939, 'recovered': 0}}

# %%
for k,v in a.items():
    print( k, v)
# Out:
# id 131
# country India
# country_code IN
# country_population 1352617328
# province
# last_updated 2020-04-29T01:39:44.895819Z
# coordinates {'latitude': '21.0', 'longitude': '78.0'}
# latest {'confirmed': 29451, 'deaths': 939, 'recovered': 0}

# %%
covid19
# Out:
# 'https://coronavirus-tracker-api.herokuapp.com'
